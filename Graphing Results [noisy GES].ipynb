# %%
import pandas as pd
import matplotlib.pyplot as plt 
import statistics as stats
import numpy as np

# %%
results = {}

# %%
# noise_lvl = 0.01

results[(0.01,10,100)] = [0.3333333333333333, 0.23333333333333334, 0.3, 0.26666666666666666, 0.26666666666666666]
results[(0.01,10,300)] = [0.5, 0.5, 0.5, 0.7333333333333333, 0.36666666666666664]
results[(0.01,10,500)] = [0.5, 0.5333333333333333, 0.5666666666666667, 0.6666666666666666, 0.4666666666666667]
results[(0.01,10,700)] = [0.5666666666666667, 0.6333333333333333, 0.6666666666666666, 0.5666666666666667, 0.7666666666666667]
results[(0.01,10,900)] = [0.7666666666666667, 0.7333333333333333, 0.6, 0.5666666666666667, 0.7333333333333333]

results[(0.01,15,100)] = [0.06666666666666667, 0.06666666666666667, 0.2, 0.1, 0.13333333333333333]
results[(0.01,15,300)] = [0.3, 0.3, 0.13333333333333333, 0.23333333333333334, 0.26666666666666666]
results[(0.01,15, 500)] = [0.3333333333333333, 0.4666666666666667, 0.43333333333333335, 0.43333333333333335, 0.4]
results[(0.01,15, 700)] = [0.4, 0.3, 0.4, 0.5333333333333333, 0.4666666666666667]
results[(0.01,15, 900)] = [0.43333333333333335, 0.36666666666666664, 0.4, 0.43333333333333335, 0.5]

results[(0.01,20,100)] = [0.1, 0.03333333333333333, 0.16666666666666666, 0.13333333333333333, 0.06666666666666667]
results[(0.01,20,300)] = [0.06666666666666667, 0.13333333333333333, 0.03333333333333333, 0.1, 0.03333333333333333]
results[(0.01,20,500)] = [0.03333333333333333, 0.23333333333333334, 0.1, 0.0, 0.16666666666666666]
results[(0.01,20,700)] = [0.1, 0.13333333333333333, 0.1, 0.13333333333333333, 0.23333333333333334]
results[(0.01,20,900)] = [0.16666666666666666, 0.23333333333333334, 0.16666666666666666, 0.2, 0.26666666666666666]

# %%
# noise_lvl = 0.1

results[(0.1,10,100)] = [0.3, 0.3333333333333333, 0.4, 0.26666666666666666, 0.4]
results[(0.1,10,300)] = [0.5333333333333333, 0.5, 0.6, 0.4666666666666667, 0.3]
results[(0.1,10,500)] = [0.5333333333333333, 0.5333333333333333, 0.4, 0.6333333333333333, 0.5666666666666667]
results[(0.1,10,700)] = [0.4666666666666667, 0.5333333333333333, 0.5666666666666667, 0.6333333333333333, 0.6666666666666666]
results[(0.1,10,900)] = [0.5333333333333333, 0.6666666666666666, 0.6666666666666666, 0.6666666666666666, 0.7]

results[(0.1,15,100)] = [0.2, 0.16666666666666666, 0.13333333333333333, 0.13333333333333333, 0.3]
results[(0.1,15,300)] = [0.2, 0.2, 0.23333333333333334, 0.26666666666666666, 0.13333333333333333]
results[(0.1,15, 500)] = [0.26666666666666666, 0.43333333333333335, 0.3333333333333333, 0.2, 0.3333333333333333]
results[(0.1,15, 700)] = [0.43333333333333335, 0.3333333333333333, 0.43333333333333335, 0.43333333333333335, 0.4666666666666667]
results[(0.1,15, 900)] = [0.6, 0.5666666666666667, 0.5, 0.36666666666666664, 0.23333333333333334]

results[(0.1,20,100)] = [0.1, 0.1, 0.13333333333333333, 0.1, 0.1]
results[(0.1,20,300)] = [0.03333333333333333, 0.1, 0.13333333333333333, 0.03333333333333333, 0.03333333333333333]
results[(0.1,20,500)] = [0.13333333333333333, 0.13333333333333333, 0.13333333333333333, 0
results[(2.,10,900)] = [0.6, 0.5, 0.7333333333333333, 0.7333333333333333, 0.7]

results[(2.,15,100)] =  [0.2, 0.16666666666666666, 0.2, 0.16666666666666666, 0.1]
results[(2.,15,300)] = [0.3, 0.26666666666666666, 0.16666666666666666, 0.13333333333333333, 0.26666666666666666]
results[(2.,15, 500)] = [0.26666666666666666, 0.13333333333333333, 0.3333333333333333, 0.43333333333333335, 0.3333333333333333]
results[(2.,15, 700)] = [0.3333333333333333, 0.3333333333333333, 0.26666666666666666, 0.43333333333333335, 0.36666666666666664]
results[(2.,15, 900)] = [0.6, 0.4, 0.5, 0.36666666666666664, 0.43333333333333335]
                        
results[(2.,20,100)] = [0.13333333333333333, 0.1, 0.13333333333333333, 0.1, 0.1]
results[(2.,20,300)] = [0.2, 0.1, 0.13333333333333333, 0.23333333333333334, 0.1]
results[(2.,20,500)] = [0.13333333333333333, 0.06666666666666667, 0.2, 0.13333333333333333, 0.13333333333333333]
results[(2.,20,700)] = [0.13333333333333333, 0.2, 0.1, 0.16666666666666666, 0.06666666666666667]
results[(2.,20,900)] = [0.26666666666666666, 0.16666666666666666, 0.26666666666666666, 0.3, 0.23333333333333334]

# %%
# noise_lvl = 4.

results[(4.,10,100)] = [0.4666666666666667, 0.13333333333333333, 0.3333333333333333, 0.36666666666666664, 0.23333333333333334]
results[(4.,10,300)] = [0.5, 0.6, 0.5666666666666667, 0.4, 0.6666666666666666]
results[(4.,10,500)] = [0.4, 0.6333333333333333, 0.4666666666666667, 0.5666666666666667, 0.5333333333333333]
results[(4.,10,700)] = [0.5666666666666667, 0.5333333333333333, 0.6, 0.5333333333333333, 0.5333333333333333]
results[(4.,10,900)] = [0.6333333333333333, 0.7333333333333333, 0.8, 0.6333333333333333, 0.7333333333333333]

results[(4.,15,100)] =  [0.16666666666666666, 0.1, 0.2, 0.1, 0.06666666666666667]
results[(4.,15,300)] = [0.2, 0.26666666666666666, 0.2, 0.26666666666666666, 0.2]
results[(4.,15, 500)] = [0.3, 0.36666666666666664, 0.3, 0.2, 0.3333333333333333]
results[(4.,15, 700)] = [0.3333333333333333, 0.36666666666666664, 0.43333333333333335, 0.36666666666666664, 0.26666666666666666]
results[(4.,15, 900)] = [0.43333333333333335, 0.4, 0.5, 0.36666666666666664, 0.4]
                        
results[(4.,20,100)] = [0.03333333333333333, 0.1, 0.1, 0.1, 0.06666666666666667]
results[(4.,20,300)] = [0.16666666666666666, 0.2, 0.03333333333333333, 0.16666666666666666, 0.1]
results[(4.,20,500)] = [0.13333333333333333, 0.13333333333333333, 0.13333333333333333, 0.16666666666666666, 0.1]
results[(4.,20,700)] = [0.3, 0.1, 0.2, 0.13333333333333333, 0.1]
results[(4.,20,900)] = [0.16666666666666666, 0.16666666666666666, 0.2, 0.16666666666666666, 0.16666666666666666]

# %%
# noise_lvl = 16.

results[(16.,10,100)] = [0.4666666666666667, 0.13333333333333333, 0.3333333333333333, 0.36666666666666664, 0.23333333333333334]
results[(16.,10,300)] = [0.5, 0.6, 0.5666666666666667, 0.4, 0.6666666666666666]
results[(16.,10,500)] = [0.4, 0.6333333333333333, 0.4666666666666667, 0.5666666666666667, 0.5333333333333333]
results[(16.,10,700)] = [0.5666666666666667, 0.5333333333333333, 0.6, 0.5333333333333333, 0.5333333333333333]
results[(16.,10,900)] = [0.6333333333333333, 0.7333333333333333, 0.8, 0.6333333333333333, 0.7333333333333333]

results[(16.,15,100)] =  [0.16666666666666666, 0.1, 0.2, 0.1, 0.06666666666666667]
results[(16.,15,300)] = [0.2, 0.26666666666666666, 0.2, 0.26666666666666666, 0.2]
results[(16.,15, 500)] = [0.3, 0.36666666666666664, 0.3, 0.2, 0.3333333333333333]
results[(16.,15, 700)] = [0.3333333333333333, 0.36666666666666664, 0.43333333333333335, 0.36666666666666664, 0.26666666666666666]
results[(16.,15, 900)] = [0.43333333333333335, 0.4, 0.5, 0.36666666666666664, 0.4]
                        
results[(16.,20,100)] = [0.03333333333333333, 0.1, 0.1, 0.1, 0.06666666666666667]
results[(16.,20,300)] = [0.16666666666666666, 0.2, 0.03333333333333333, 0.16666666666666666, 0.1]
results[(16.,20,500)] = [0.13333333333333333, 0.13333333333333333, 0.13333333333333333, 0.16666666666666666, 0.1]
results[(16.,20,700)] = [0.3, 0.1, 0.2, 0.13333333333333333, 0.1]
results[(16.,20,900)] = [0.16666666666666666, 0.16666666666666666, 0.2, 0.16666666666666666, 0.16666666666666666]

# %%
results_per_d_mean = {}

results_mean = np.zeros((50, 901))
results_CI = np.zeros((50, 901))

noise_lvl = 4.
    
for d in [10,15,20]:
    for n in range(100, 901, 200):
        results_mean[d, n] = np.mean(results[(noise_lvl,d,n)][:5]) 
        results_CI[d, n] = 0.878 * stats.stdev(results[(noise_lvl,d,n)][:5])

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("0.01 Noise")
plt.savefig("graph_0.01_noise.pdf");

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("0.1 Noise")
plt.savefig("graph_0.1_noise.pdf");

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("0.3 Noise")
plt.savefig("graph_0.3_noise.pdf");

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("0.5 Noise")
plt.savefig("graph_0.5_noise.pdf");

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("1. Noise")
plt.savefig("graph_1._noise.pdf");

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("2. Noise")
plt.savefig("graph_2._noise.pdf");

# %%
plt.plot(range(100,901, 200), results_mean[10,100::200], 'g-', label="d="+str(10))
plt.plot(range(100,901, 200), results_mean[10,100::200] - results_CI[10,100::200], 'g--')
plt.plot(range(100,901, 200), results_mean[10,100::200] + results_CI[10,100::200], 'g--')

plt.plot(range(100,901, 200), results_mean[15,100::200], 'y-', label="d="+str(15))
plt.plot(range(100,901, 200), results_mean[15,100::200] - results_CI[15,100::200], 'y--')
plt.plot(range(100,901, 200), results_mean[15,100::200] + results_CI[15,100::200], 'y--')

plt.plot(range(100,901, 200), results_mean[20,100::200], 'r-', label="d="+str(20))
plt.plot(range(100,901, 200), results_mean[20,100::200] - results_CI[20,100::200], 'r--')
plt.plot(range(100,901, 200), results_mean[20,100::200] + results_CI[20,100::200], 'r--')

plt.ylim((0,1.))
plt.xlabel('# datapoints')
plt.ylabel('success rate')
plt.legend()
plt.title("4. Noise")
plt.savefig("graph_4._noise.pdf");
